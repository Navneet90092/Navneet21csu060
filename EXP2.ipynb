# %% [markdown]
# <a href="https://colab.research.google.com/github/Navneet90092/Navneet21csu060/blob/main/RL1_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
np.random .seed(1)

# %%
# 1000 random integers between 0 and 50
x = np.random.randint(0, 50, 1000)
print(x)
# Out:
# [37 43 12  8  9 11  5 15  0 16  1 12  7 45  6 25 20 37 18 20 11 42 28 29
#  14  4 23 23 41 49 30 32 22 13 41  9  7 22  1  0 17  8 24 13 47 42  8 30
#   7  3  6 21 49  3  4 24 49 43 12 26 16 45 41 18 15  0  4 25 47 34 23  7
#  26 25 40 22  9  3 39 23 36 27 37 19 38  8 32 34 10 23 15 47 23 25  7 28
#  10 46 32 24 23  1 49 13  3  0 13  6 21  6  2 12 27 21 11  7 13  8 11 12
#  43 20 30 36 39  7 45  4 48 18 32 13 10 23 17  7 24 10 28 20 32 12  1 30
#  41 24 18 33  2 44 28 39 34 10 32 41 18 22  6  2  7 39 48 15  5 17 42 20
#  48 22 37 13 49 33 20 10 32 25 21 39 32 19 25 49 14 13 20 43  6 13 15 24
#   9  2  7  5 36 37 21 40 13 27 49 49 47 13 40 14 45 23 16 28 42 45  3  2
#  14 46  0 29 11 35 29 33  2 20 19 48 32 28 18 31 28 30 10  8 45 35 32  8
#  20 13 15 41  0 44 19 24 49 42 20 44 15 30 27 14 19 26 43 22  7 35 47 46
#  34 36 36 32 19  3 24 19 37 30 38 47 39  5 15 49 23 32 42 10  2 24 34 30
#  17  4  0 14 17 39 35 17 28 22 38 41 10 13  6 25 38 48 48 44 41  0 22 16
# ...

# %%
y = x+ np.random.normal(0, 10, 1000)
#positive correlation with some noise
y = x + np.random.normal(0, 10, 1000)

# %%
np.corrcoef(x, y)
# Out:
# array([[1.        , 0.81236628],
#        [0.81236628, 1.        ]])

# %%
from ast import increment_lineno
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
y = x - np.random.normal(0, 10, 1000)
#positive correlation with some noise
y = x - np.random.normal(0, 10, 1000)
print (y)
# Out:
# [ 3.06361127e+01  4.41964547e+01  2.12280789e+01  2.23015016e+01
#  -8.48684759e-01 -7.03238746e+00  7.37000959e+00  3.70214853e+01
#   4.40935830e+00  1.43668780e+01 -1.34710395e+01  5.76069531e+00
#   1.32041620e+01  3.86277435e+01 -7.36751341e+00  1.68392905e+01
#   2.30106025e+01  2.86210342e+01  1.27493017e+01  2.24108261e+00
#   2.33542368e+01  5.49870754e+01  2.90271700e+01  2.00467070e+01
#   9.90700622e+00  4.14923426e+00  4.07992667e+01  3.50400635e+01
#   4.29300877e+01  5.62244279e+01  3.21913650e+01  3.39144284e+01
#   3.24172510e+01  1.70402039e+01  2.99970488e+01  2.02638678e+01
#   1.19627038e+01  1.33946146e+01 -1.21044775e+01  8.34662899e+00
#   2.30666918e+01  2.78115343e+00  1.51290376e+01  1.52426091e+01
#   4.84672955e+01  4.78832048e+01  2.22193499e+01  3.53959626e+01
#   2.45195682e+00 -7.48048800e+00 -1.25057974e+01  2.30766407e+01
#   4.66026206e+01  6.73739619e+00  3.73739852e+00  4.30683901e+01
# ...

# %%
np.corrcoef(x,y)
# Out:
# array([[1.        , 0.82275202],
#        [0.82275202, 1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
y=100-x +np.random.normal(0, 10, 1000)
np.corrcoef(x , y)
# Out:
# array([[ 1.        , -0.81174767],
#        [-0.81174767,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x, y)
plt.show()

# %%
z=200-x +np.random.normal(0, 10, 1000)
np.corrcoef(x , z)
# Out:
# array([[ 1.        , -0.83103233],
#        [-0.83103233,  1.        ]])

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(x , z)
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib Inline
matplotlib.style.use('ggplot')

plt.scatter(y, z)
plt.show()

# %%
import pandas as pd
df = pd.DataFrame({'a': np.random.randint(0, 50,1000)})
df['b'] = df['a'] + np.random.normal(0,10,1000)
df['c'] = 100-df['a'] + np.random.normal(0,5,1000)
df['d'] = np.random.randint(0,50,1000)

df.corr()
# Out:
#           a         b         c         d
# a  1.000000  0.836570 -0.946792 -0.025969
# b  0.836570  1.000000 -0.795570  0.004428
# c -0.946792 -0.795570  1.000000  0.010166
# d -0.025969  0.004428  0.010166  1.000000

# %%
pd.plotting.scatter_matrix(df,figsize=(6,6))
plt.show()

# %%
plt.matshow(df.corr())
plt.xticks(range(len(df.columns)),df.columns)
plt.yticks(range(len(df.columns)),df.columns)
plt.colorbar()
plt.show()
